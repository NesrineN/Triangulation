# %% [markdown]
# C2 Rotated Left Configuration

# %%
import matplotlib.pyplot as plt

sigma = list(range(11))

lin_eigen = [0.000343,0.176491,0.338040,0.495386,0.637118,0.716811,0.897496,1.141574,1.189721,1.340095,1.405813]
lin_ls    = [0.000343,0.611366,7.710582,15.547405,16.506364,22.126627,24.782450,29.977179,28.796606,27.980306,30.909535]
iter_eigen= [0.000343,0.176491,0.338040,0.495386,0.637119,0.716812,0.897497,1.141574,1.189722,1.340095,1.405813]
iter_ls   = [0.000343,0.176362,2.082043,3.518327,6.651059,10.542962,13.686826,17.737683,19.428029,20.891374,22.913698]
poly      = [0.152855,0.197256,0.320241,0.500142,0.637326,0.739139,0.908409,1.141224,1.170652,1.337043,1.381913]
poly_abs  = [0.843109,0.868721,0.934223,1.033477,1.111957,1.179805,1.305209,1.506695,1.540644,1.671743,1.725506]
kanatani  = poly
higher    = poly

plt.figure()

plt.plot(sigma, lin_eigen, label="Lin_Eigen")
plt.plot(sigma, lin_ls, label="Lin_LS")
plt.plot(sigma, iter_eigen, label="Iter_Eigen")
plt.plot(sigma, iter_ls, label="Iter_LS")
plt.plot(sigma, poly, label="Poly")
plt.plot(sigma, poly_abs, label="Poly_Abs")
plt.plot(sigma, kanatani, label="Kanatani")
plt.plot(sigma, higher, label="HigherOrd")

plt.xlabel("Noise level (sigma)")
plt.ylabel("Percentage error (%)")
plt.title("Triangulation Robustness to Noise")
plt.legend()
plt.grid()

plt.show()

# %%
import matplotlib.pyplot as plt

sigma = list(range(11))

lin_eigen = [0.000343, 0.176491, 0.338040, 0.495386, 0.637118, 0.716811, 0.897496, 1.141574, 1.189721, 1.340095, 1.405813]
lin_ls    = [0.000343, 0.611366, 7.710582, 15.547405, 16.506364, 22.126627, 24.782450, 29.977179, 28.796606, 27.980306, 30.909535]
iter_eigen= [0.000343, 0.176491, 0.338040, 0.495386, 0.637119, 0.716812, 0.897497, 1.141574, 1.189722, 1.340095, 1.405813]
iter_ls   = [0.000343, 0.176362, 2.082043, 3.518327, 6.651059, 10.542962, 13.686826, 17.737683, 19.428029, 20.891374, 22.913698]
poly      = [0.152855, 0.197256, 0.320241, 0.500142, 0.637326, 0.739139, 0.908409, 1.141224, 1.170652, 1.337043, 1.381913]
poly_abs  = [0.843109, 0.868721, 0.934223, 1.033477, 1.111957, 1.179805, 1.305209, 1.506695, 1.540644, 1.671743, 1.725506]
kanatani  = poly
higher    = poly

plt.figure()

plt.plot(sigma, lin_eigen, label="Lin_Eigen")
plt.plot(sigma, lin_ls, label="Lin_LS")
plt.plot(sigma, iter_eigen, label="Iter_Eigen")
plt.plot(sigma, iter_ls, label="Iter_LS")
plt.plot(sigma, poly, label="Poly")
plt.plot(sigma, poly_abs, label="Poly_Abs")
plt.plot(sigma, kanatani, label="Kanatani")
plt.plot(sigma, higher, label="HigherOrd")

plt.xlabel("Noise level (sigma)")
plt.ylabel("Percentage error (%)")
plt.title("Triangulation Robustness to Noise")
plt.legend()
plt.grid()

# Recommended for better visibility:
# plt.yscale("log")

plt.show()

# %% [markdown]
# Horizontal Configuration

# %%
import matplotlib.pyplot as plt

sigma = list(range(11))

lin_eigen = [0.0, 0.176237, 0.337400, 0.494658, 0.637651, 0.717267, 0.897876, 1.143437, 1.189009, 1.340092, 1.405829]
lin_ls    = [0.0, 43.717056, 43.372820, 43.431407, 43.471842, 43.486337, 43.311408, 43.333261, 43.540511, 43.580418, 43.358229]
iter_eigen= [0.0, 0.176237, 0.337400, 0.494658, 0.637651, 0.717267, 0.897876, 1.143437, 1.189009, 1.340092, 1.405829]
iter_ls   = [0.0, 43.717056, 43.372820, 43.431407, 43.471842, 43.486337, 43.311408, 43.333261, 43.540511, 43.580418, 43.358229]
poly      = [0.0, 0.176238, 0.337402, 0.494660, 0.637652, 0.717264, 0.897876, 1.143437, 1.189029, 1.340078, 1.405847]
poly_abs  = [0.0, 0.176788, 0.338262, 0.496028, 0.638835, 0.721051, 0.900243, 1.146790, 1.193201, 1.344104, 1.411408]
kanatani  = poly
higher    = poly

plt.figure()

plt.plot(sigma, lin_eigen, label="Lin_Eigen")
plt.plot(sigma, lin_ls, label="Lin_LS")
plt.plot(sigma, iter_eigen, label="Iter_Eigen")
plt.plot(sigma, iter_ls, label="Iter_LS")
plt.plot(sigma, poly, label="Poly")
plt.plot(sigma, poly_abs, label="Poly_Abs")
plt.plot(sigma, kanatani, label="Kanatani")
plt.plot(sigma, higher, label="HigherOrd")

plt.xlabel("Noise level (sigma)")
plt.ylabel("Percentage error (%)")
plt.title("Triangulation Robustness to Noise")
plt.legend()
plt.grid()

plt.show()

# %%
import matplotlib.pyplot as plt

sigma = list(range(11))

lin_eigen = [0.0, 0.176237, 0.337400, 0.494658, 0.637651, 0.717267, 0.897876, 1.143437, 1.189009, 1.340092, 1.405829]
lin_ls    = [0.0, 43.717056, 43.372820, 43.431407, 43.471842, 43.486337, 43.311408, 43.333261, 43.540511, 43.580418, 43.358229]
iter_eigen= [0.0, 0.176237, 0.337400, 0.494658, 0.637651, 0.717267, 0.897876, 1.143437, 1.189009, 1.340092, 1.405829]
iter_ls   = [0.0, 43.717056, 43.372820, 43.431407, 43.471842, 43.486337, 43.311408, 43.333261, 43.540511, 43.580418, 43.358229]
poly      = [0.0, 0.176238, 0.337402, 0.494660, 0.637652, 0.717264, 0.897876, 1.143437, 1.189029, 1.340078, 1.405847]
poly_abs  = [0.0, 0.176788, 0.338262, 0.496028, 0.638835, 0.721051, 0.900243, 1.146790, 1.193201, 1.344104, 1.411408]
kanatani  = poly
higher    = poly

plt.figure()

plt.plot(sigma, lin_eigen, label="Lin_Eigen")
plt.plot(sigma, lin_ls, label="Lin_LS")
plt.plot(sigma, iter_eigen, label="Iter_Eigen")
plt.plot(sigma, iter_ls, label="Iter_LS")
plt.plot(sigma, poly, label="Poly")
plt.plot(sigma, poly_abs, label="Poly_Abs")
plt.plot(sigma, kanatani, label="Kanatani")
plt.plot(sigma, higher, label="HigherOrd")

plt.xlabel("Noise level (sigma)")
plt.ylabel("Percentage error (%)")
plt.title("Triangulation Robustness to Noise")
plt.legend()
plt.grid()

# Recommended for this dataset due to large gap:
# plt.yscale("log")

plt.show()
